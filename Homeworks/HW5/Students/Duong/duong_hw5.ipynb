# %% [markdown]
# ## <center>Computer Science Intensive Course - MindX</center>
# ![](./assets/logo.png)
# # <center>HOMEWORK 5. THUẬT TOÁN SẮP XẾP (1)</center>

# %% [markdown]
# ## Bài Tập: Danh Sách Từ
#
# Cho danh sách 100 từ tiếng Anh thông dụng nhất, mỗi từ cách nhau bằng một dấu cách. Hãy sắp xếp danh sách trên theo quy tắc sau:
# - Từ có ít chữ cái hơn đứng trước
# - Nếu hai từ có cùng số chữ cái, từ nào có thứ tự nhỏ hơn trong bảng chữ cái đứng trước (dùng phép so sánh < hoặc > trên *string*)
#
# **Input**: *most_common_100*
# **Output**: Một *string* với cùng định dạng, nhưng các từ được sắp xếp theo quy tắc như trên.

# %%
most_common_100 = "the of to and a in is it you that he was for on are with as I his they be at one have this from or had by hot but some what there we can out other were all your when up use word how said an each she which do their time if will way about many then them would write like so these her long make thing see him two has look more day could go come did my sound no most number who over know water than call first people may down side been now find"

# %%
#Một cái gì đó rất nhảm và chẳng có tác dụng gì
from time import sleep, time
import os, glob, sys
x = 5
y = 0
def dick():
	while y > x:
		print("y is smol")
		x = x + 1

class person:
    def __init__(self, IQ, PWR):
        self.IQ = IQ
        self.PWR = PWR
    
    def addup(self):
        return self.IQ + self.PWR
def win(l):
    if j > l:
        print('John wins')
    elif j == l:
        print("It's a tie")
    else:
        print('Luke wins')
 
how_many_time = 0
CAN_loop = True
can_do = True
duong_ok = "duong : no you are stupid"
duong_ngu = most_common_100.split()
someone_who_hates_duong_ok = "someone_ưho_hates_duôngkay? : no Duong is stupid"
def sapxep(list_of_strings):
    if list_of_strings < 3:
        return 0
    
    prime_arr = [True] * (n)
    prime_arr[0] = False
    prime_arr[1] = False
    
    listsnt = [] #Chua cac so nguyen to
    for i in range(2,list_of_strings):
        if prime_arr[i]:
            listsnt.append(i)
            
            for j in range(2,(int((list_of_strings-1)//i)+1)):
                prime_arr[i*j] = False
    
    for i in range(len(listsnt)-1):
        if listsnt[i]*listsnt[i+1]<=list_of_strings:
            result = listsnt[i],listsnt[i+1]
    
    return list_of_strings - result[0]*result[1] 
while CAN_loop:
    if can_do:
        print(duong_ok)
        sleep(0.3)
        how_many_time = how_many_time + 1
        can_do = False
    elif can_do == False:
        print(someone_who_hates_duong_ok)
        sleep(0.3)
        can_do = True
        if how_many_time==5:
            sleep(1)
            print("duong : wait? are we both stupid?")
            sleep(1)
            print("someone_who_hates_duong : ye i think so")
            sleep(1)
            print("duong : yay. both stupid best friends")
            sleep(1)
            print("someone_who_hates_duong : ye")
            sleep(1)
            print("duong : so we are ")
            sleep(1)
            print("someone_who_hates_duong : emmm, i still think Duongu is still more stupid than me")
            someone_who_hates_duong_ok = "someone_who_hates_duong : no Duong is more stupid"
            duong_ok = "duong : no youre are more stupid" 
            for i in range(len(duong_ngu)):
                for j in range(len(duong_ngu)-1-i):
                    if len(duong_ngu[j]) > len(duong_ngu[j+1]):
                        duong_ngu[j],duong_ngu[j+1] = duong_ngu[j+1],duong_ngu[j]
                    elif len(duong_ngu[j]) == len(duong_ngu[j+1]) and duong_ngu[j] > duong_ngu[j+1]:
                        duong_ngu[j],duong_ngu[j+1] = duong_ngu[j+1],duong_ngu[j]
            print('Duongu has some thing up his sleeve, wait wait wait')            
            print('Duongu said',*duong_ngu,sep=' ')      
            while CAN_loop:
                if can_do:
                    print(duong_ok)
                    sleep(0.3)
                    how_many_time = how_many_time + 1
                    can_do = False
                    
                elif can_do == False:
                    print(someone_who_hates_duong_ok)
                    sleep(0.3)
                    can_do = True
# Out:
# duong : no you are stupid
# someone_ưho_hates_duôngkay? : no Duong is stupid
# duong : no you are stupid
# someone_ưho_hates_duôngkay? : no Duong is stupid
# duong : no you are stupid
# someone_ưho_hates_duôngkay? : no Duong is stupid
# duong : no you are stupid
# someone_ưho_hates_duôngkay? : no Duong is stupid
# duong : no you are stupid
# someone_ưho_hates_duôngkay? : no Duong is stupid
# duong : wait? are we both stupid?
# someone_who_hates_duong : ye i think so
# duong : yay. both stupid best friends
# someone_who_hates_duong : ye
# duong : so we are
# someone_who_hates_duong : emmm, i still think Duongu is still more stupid than me
# Duongu has some thing up his sleeve, wait wait wait
# ...
